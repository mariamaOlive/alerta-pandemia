# %%
import pandas as pd
vendas1 = pd.read_csv("venda_passagem_02_2019.csv",encoding='latin1',sep=";")
vendas2= pd.read_csv("municipio.csv",encoding='latin2',sep=",")
vendas1.columns = ['MesEmissão','MesViagem','Origem','Destino','UFOrigem','UFDestino','mediavalor','dpvalototal','quantidadebilhetes']
vendas1 = vendas1.drop('mediavalor', axis=1)
vendas1 = vendas1.drop('dpvalototal', axis=1)
vendas1["Origem"],vendas1["UFOrigem"] = vendas1["Origem"].str.split('/').str
vendas1["Destino"],vendas1["UFDestino"]= vendas1["Destino"].str.split('/').str
vendas1= vendas1[['MesEmissão','MesViagem','Origem','UFOrigem','Destino','UFDestino','quantidadebilhetes']]
display(vendas1)
display(vendas2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 import pandas as pd
#       2 vendas1 = pd.read_csv("venda_passagem_02_2019.csv",encoding='latin1',sep=";")
#       3 vendas2= pd.read_csv("municipio.csv",encoding='latin2',sep=",")
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
dfS2 = pd.read_csv("C:/Users/lucas/Desktop/cases-brazil-cities-time_2020.csv")

mask = dfS2['state'] != "RJ"
# exclui as linhas que atendem ao critério
df = dfS2.drop(index=dfS2[mask].index)
df1 = dfS2.drop(index=dfS2[mask].index)
df1.to_excel(f"C:/Users/lucas/Desktop/aa1.xlsx", index=False)

display(df1)
# Out:
#          epi_week        date state               city   ibgeID  newDeaths  \
# 18             10  2020-03-05    RJ     Barra Mansa/RJ  3300407          0
# 21             10  2020-03-06    RJ     Barra Mansa/RJ  3300407          0
# 25             10  2020-03-06    RJ  Rio de Janeiro/RJ  3304557          0
# 28             10  2020-03-07    RJ     Barra Mansa/RJ  3300407          0
# 33             10  2020-03-07    RJ  Rio de Janeiro/RJ  3304557          0
# ...           ...         ...   ...                ...      ...        ...
# 1314077        53  2020-12-31    RJ       Três Rios/RJ  3306008          1
# 1314196        53  2020-12-31    RJ         Valença/RJ  3306107          0
# 1314216        53  2020-12-31    RJ       Varre-Sai/RJ  3306156          0
# 1314219        53  2020-12-31    RJ       Vassouras/RJ  3306206          0
# 1314305        53  2020-12-31    RJ   Volta Redonda/RJ  3306305          8
#
# ...

# %%
left = vendas1
right = vendas2
df_final = pd.merge(
    left,
    right,
    how="left",
    left_on='Cod_setor',
    right_on='CD_GEOCODI',    
    left_index=False,
    right_index=False,
    suffixes=("_l", "_r"),
    copy=True,
    validate=None,
)
display(df_final)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\lucas\Desktop\ufrpe\arq\alerta-pandemia\merge.ipynb Cell 3 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lucas/Desktop/ufrpe/arq/alerta-pandemia/merge.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> left = vendas1
#       <a href='vscode-notebook-cell:/c%3A/Users/lucas/Desktop/ufrpe/arq/alerta-pandemia/merge.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> right = vendas2
#       <a href='vscode-notebook-cell:/c%3A/Users/lucas/Desktop/ufrpe/arq/alerta-pandemia/merge.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> df_final = pd.merge(
#       <a href='vscode-notebook-cell:/c%3A/Users/lucas/Desktop/ufrpe/arq/alerta-pandemia/merge.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a>     left,
#       <a href='vscode-notebook-cell:/c%3A/Users/lucas/Desktop/ufrpe/arq/alerta-pandemia/merge.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a>     right,
#    (...)
# ...
