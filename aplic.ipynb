# %%
import pandas as pd

df = pd.read_csv("ibge_dnit.csv")

display(df)
# Out:
#          origem  destino   ibge  dnit_2016_1  dnit_pessoas_2016_1  \
# 0       5103809  5108402   42.0     0.874651                  9.0
# 1       1501204  1504604   68.0          NaN                  NaN
# 2       1502103  1504604    6.0          NaN                  NaN
# 3       2300150  2304400  716.0          NaN                  NaN
# 4       2304400  2311603  645.0          NaN                  NaN
# ...         ...      ...    ...          ...                  ...
# 330386  5300108  5219258    NaN          NaN                  NaN
# 330387  5300108  5219506    NaN          NaN                  NaN
# 330388  5300108  5219902    NaN          NaN                  NaN
# 330389  5300108  5220504    NaN          NaN                  NaN
# 330390  5300108  5222203    NaN          NaN                  NaN
#
#         dnit_sel_2016_1  dnit_pessoas_sel_2016_1  dnit_2016_2  \
# 0                   NaN                      NaN          NaN
# ...

# %%
dfFluxo = pd.read_csv("./dados_final/4_dados_calculados/arr_calculo_qtd_fluxo.csv")

display(dfFluxo)
# Out:
#         cod_origem  cod_destino  passageiros_rodov  passageiros_aereo  \
# 0          1100106      1100205              381.0                0.0
# 1          1100205      1100106              763.0                0.0
# 2          1100205      2105302                6.0                0.0
# 3          1100205      2111300               10.0                0.0
# 4          1100205      2611606                4.0                0.0
# ...            ...          ...                ...                ...
# 123972     5222203      5218300               44.0                0.0
# 123973     5222302      5201108               19.0                0.0
# 123974     5222302      5205513               18.0                0.0
# 123975     5222302      5205802               10.0                0.0
# 123976     5222302      5217302                9.0                0.0
#
#         passageiros_total  prob_rodov  prob_aereo  prob_total
# 0                   381.0    0.758964         0.0    0.758964
# ...
