# %% [markdown]
# # Validação do Sistema
# Estes dados de validação aparecem no artigo submetido para SBBD 2013

# %%
import pandas as pd
import os
import glob

# %%
from scipy import stats
def avaliar_corr(df, coluna_base):

    corr_df = pd.DataFrame(columns = ["r", "p"])

    for col in df:
        if pd.api.types.is_numeric_dtype(df[col]):
            r, p = stats.spearmanr(df[coluna_base], df[col])
            corr_df.loc[col] = [round(r,4), p ]
    
    return corr_df

# %% [markdown]
# ## Carregando datasets

# %%
#Dataset Arranjos e Municípios
df_arr_mun = pd.read_csv("../dados_final/2_dados_sem_enriquecimento/arr_mun.csv")

#Dataset de estados
df_estado = pd.read_csv("../dados_final/2_dados_sem_enriquecimento/estado.csv")

#Dataset probabilidades
df_prob = pd.read_csv("../dados_final/4_dados_calculados/arr_calculo_qtd_fluxo.csv")

#Dataset casos iniciais (Alpha)
df_alpha = pd.read_csv("data/brazil_covid19.csv")

#Dataset casos Gamma
# Carregando lista de arquivos .tsv
path = "../data_fiocruz"
tsv_files = glob.glob(os.path.join(path, "*.tsv"))
df_list = []
for f in tsv_files: 
    df_list.append(pd.read_csv(f, sep='\t'))
# Juntando dados em um único dataframe
df_gamma = pd.concat(df_list)

# %% [markdown]
# ### Tratamento de dados

# %% [markdown]
# DF de probabilidades

# %%
#Adicionando info ao df de probabilidades

df_prob = df_prob.merge(df_arr_mun[["cod_cidade","uf"]], left_on="cod_origem", right_on="cod_cidade")\
        .rename(columns={"uf": "uf_origem"})\
        .drop(columns="cod_cidade")

df_prob = df_prob.merge(df_arr_mun[["cod_cidade","uf"]], left_on="cod_destino", right_on="cod_cidade")\
        .rename(columns={"uf": "uf_destino"})\
        .drop(columns="cod_cidade")

# %% [markdown]
# DF da Alpha

# %%
df_alpha["date"] = df_alpha["date"].apply(pd.to_datetime)

# %% [markdown]
# DF da Gamma

# %%
# Tranformando datas em tipo date 
df_gamma[["Collection date", "Submission date"]] = df_gamma[["Collection date", "Submission date"]].apply(pd.to_datetime)
#Removendo casos antes de Manaus --> Segundo Ricardo foram inputados errados
df_gamma = df_gamma[df_gamma["Collection date"]>="2020-12-03"]	

# Separando colunas de localidade
df_gamma[['continent','country','state','municipality']] = df_gamma['Location'].str.split(' / ', expand = True)

#Definindo UF do caso
from unicodedata import normalize
import re
def match_codigo(estado):
    estado = (normalize('NFKD', estado).encode('ASCII','ignore').decode('ASCII')).upper()
    return [re.sub(r"[^a-zA-Z0-9]+", ' ', k) for k in estado.split("\n")][0]

df_gamma.loc[df_gamma["state"]=="Federal District", "state"] = "Distrito Federal"
df_gamma["state"] = df_gamma.apply(lambda linha: match_codigo(linha.state), axis= 1)
df_estado["nome_uf"] = df_estado.apply(lambda linha: match_codigo(linha.nome_uf), axis= 1)
df_gamma = df_gamma.merge(df_estado[["nome_uf", "uf"]], left_on="state", right_on="nome_uf").drop(columns=["nome_uf"])

#Casos acumulados por estados
df_gamma = df_gamma.sort_values(by='Collection date')
df_gamma["case"] = 1
df_gamma["cases"] = df_gamma.groupby("uf")["case"].cumsum()

# %%
display(df_arr_mun)
display(df_prob)
display(df_alpha)
display(df_gamma)
# Out:
#       cod_cidade                                        nome_cidade  \
# 0        1100106  Arranjo Populacional Internacional de Guajará-...
# 1        1100205             Arranjo Populacional de Porto Velho/RO
# 2        1200054  Arranjo Populacional Internacional de Assis Br...
# 3        1200104  Arranjo Populacional Internacional de Cobija/B...
# 4        1303007                Arranjo Populacional de Nhamundá/AM
# ...          ...                                                ...
# 4894     1508407                                           Xinguara
# 4895     2933604                                        Xique-Xique
# 4896     2517407                                             Zabelê
# 4897     3557154                                           Zacarias
# 4898     2114007                                            Zé Doca
#
#       populacao_2021       area  latitude  longitude  cod_uf    nome_uf  uf  \
# 0            46930.0  24856.877 -10.78890   -65.3296      11   Rondônia  RO
# 1           577020.0  40934.820  -8.76077   -63.8999      11   Rondônia  RO
# 2             7649.0   4979.073 -10.92980   -69.5738      12       Acre  AC
# 3            46102.0   5580.848 -10.99500   -68.7497      12       Acre  AC
# 4            28659.0  25878.709  -2.20793   -56.7112      13   Amazonas  AM
# ...              ...        ...       ...        ...     ...        ...  ..
# 4894         45416.0   3779.348  -7.09830   -49.9437      15       Pará  PA
# 4895         46562.0   5079.662 -10.82300   -42.7245      29      Bahia  BA
# 4896          2269.0    106.811  -8.07901   -37.1057      25    Paraíba  PB
# 4897          2784.0    319.056 -21.05060   -50.0552      35  São Paulo  SP
# 4898         52190.0   2140.109  -3.27014   -45.6553      21   Maranhão  MA
#
#      pais  densidade_2021
# 0     BRA        1.888009
# 1     BRA       14.096068
# 2     BRA        1.536230
# 3     BRA        8.260752
# 4     BRA        1.107435
# ...   ...             ...
# 4894  BRA       12.016888
# 4895  BRA        9.166358
# 4896  BRA       21.243130
# 4897  BRA        8.725741
# 4898  BRA       24.386608
#
# [4899 rows x 11 columns]
#         cod_origem  cod_destino  passageiros_rodov  passageiros_aereo  \
# 0          1100106      1100205              381.0                0.0
# 1          1501402      1100205                0.0             1126.0
# 2          2105302      1100205                5.0                0.0
# 3          2111300      1100205                2.0                0.0
# 4          2611606      1100205                1.0               54.0
# ...            ...          ...                ...                ...
# 118569     3526308      3550001              138.0                0.0
# 118570     3550001      3526308              251.0                0.0
# 118571     5101605      5107800               48.0                0.0
# 118572     5104203      5108105                2.0                0.0
# 118573     5107800      5101605                7.0                0.0
#
#         passageiros_total  prob_rodov  prob_aereo  prob_total uf_origem  \
# 0                   381.0    0.758964    0.000000    0.758964        RO
# 1                  1126.0    0.000000    0.000652    0.000611        PA
# 2                     5.0    0.000080    0.000000    0.000021        MA
# 3                     2.0    0.000020    0.000000    0.000002        MA
# 4                    55.0    0.000002    0.000013    0.000012        PE
# ...                   ...         ...         ...         ...       ...
# 118569              138.0    1.000000    0.000000    1.000000        SP
# 118570              251.0    1.000000    0.000000    1.000000        SP
# 118571               48.0    1.000000    0.000000    1.000000        MT
# 118572                2.0    0.004926    0.000000    0.004926        MT
# 118573                7.0    1.000000    0.000000    1.000000        MT
#
#        uf_destino
# 0              RO
# 1              RO
# 2              RO
# 3              RO
# 4              RO
# ...           ...
# 118569         SP
# 118570         SP
# 118571         MT
# 118572         MT
# 118573         MT
#
# [118574 rows x 10 columns]
#             date        region state      cases  deaths
# 0     2020-02-25  Centro-Oeste    DF        0.0       0
# 1     2020-02-25  Centro-Oeste    GO        0.0       0
# 2     2020-02-25  Centro-Oeste    MS        0.0       0
# 3     2020-02-25  Centro-Oeste    MT        0.0       0
# 4     2020-02-25      Nordeste    AL        0.0       0
# ...          ...           ...   ...        ...     ...
# 12253 2021-05-23       Sudeste    RJ   840480.0   49515
# 12254 2021-05-23       Sudeste    SP  3188105.0  107614
# 12255 2021-05-23           Sul    PR  1060683.0   25506
# 12256 2021-05-23           Sul    RS  1059990.0   27419
# 12257 2021-05-23           Sul    SC   947810.0   14822
#
# [12258 rows x 5 columns]
#            Accession ID Collection date Submission date  \
# 43945   EPI_ISL_2777382      2020-12-03      2021-07-02
# 44399   EPI_ISL_2777388      2020-12-04      2021-07-02
# 43277    EPI_ISL_833137      2020-12-04      2021-01-17
# 43347   EPI_ISL_1060879      2020-12-06      2021-02-23
# 43943   EPI_ISL_2777384      2020-12-07      2021-07-02
# ...                 ...             ...             ...
# 28585   EPI_ISL_8721279      2021-12-30      2022-01-14
# 27333   EPI_ISL_8721616      2021-12-30      2022-01-14
# 27312   EPI_ISL_8721650      2021-12-30      2022-01-14
# 28594   EPI_ISL_9303894      2022-01-10      2022-01-31
# 4239   EPI_ISL_14498244      2022-02-20      2022-08-17
#
#                                          Location      continent country  \
# 43945  South America / Brazil / Amazonas / Manaus  South America  Brazil
# 44399  South America / Brazil / Amazonas / Manaus  South America  Brazil
# 43277  South America / Brazil / Amazonas / Manaus  South America  Brazil
# 43347  South America / Brazil / Amazonas / Manaus  South America  Brazil
# 43943  South America / Brazil / Amazonas / Manaus  South America  Brazil
# ...                                           ...            ...     ...
# 28585          South America / Brazil / Sao Paulo  South America  Brazil
# 27333          South America / Brazil / Sao Paulo  South America  Brazil
# 27312          South America / Brazil / Sao Paulo  South America  Brazil
# 28594          South America / Brazil / Sao Paulo  South America  Brazil
# 4239    South America / Brazil / Bahia / Salvador  South America  Brazil
#
#            state municipality  uf  case  cases
# 43945   AMAZONAS       Manaus  AM     1      1
# 44399   AMAZONAS       Manaus  AM     1      2
# 43277   AMAZONAS       Manaus  AM     1      3
# 43347   AMAZONAS       Manaus  AM     1      4
# 43943   AMAZONAS       Manaus  AM     1      5
# ...          ...          ...  ..   ...    ...
# 28585  SAO PAULO         None  SP     1  26826
# 27333  SAO PAULO         None  SP     1  26827
# 27312  SAO PAULO         None  SP     1  26828
# 28594  SAO PAULO         None  SP     1  26829
# 4239       BAHIA     Salvador  BA     1   1773
#
# [53810 rows x 11 columns]

# %% [markdown]
# ## Risco das cidades

# %% [markdown]
# ### Variante Alpha

# %% [markdown]
# Por cidade

# %% [markdown]
# Por estado

# %%
#Removendo o estado de SP da análise
df_alpha_no_sp = df_alpha[df_alpha["state"]!="SP"]

# %% [markdown]
# Rank por 1 caso

# %%
df_more_1 = df_alpha_no_sp[df_alpha_no_sp["cases"]>=1]
df_more_1 = df_more_1[~df_more_1.duplicated(subset=["state"])]
df_more_1["rank"] = df_more_1["date"].rank(method='dense').astype(int)
df_more_1
# Out:
#           date        region state  cases  deaths  rank
# 265 2020-03-05       Sudeste    RJ    1.0       0     1
# 275 2020-03-06      Nordeste    BA    1.0       0     2
# 290 2020-03-06       Sudeste    ES    1.0       0     2
# 297 2020-03-07  Centro-Oeste    DF    1.0       0     3
# 328 2020-03-08      Nordeste    AL    1.0       0     4
# 345 2020-03-08       Sudeste    MG    1.0       0     4
# 403 2020-03-10           Sul    RS    1.0       0     5
# 441 2020-03-12      Nordeste    PE    2.0       0     6
# 456 2020-03-12           Sul    PR    6.0       0     6
# 460 2020-03-13  Centro-Oeste    GO    3.0       0     7
# 470 2020-03-13      Nordeste    RN    1.0       0     7
# 485 2020-03-13           Sul    SC    2.0       0     7
# 525 2020-03-15      Nordeste    SE    1.0       0     8
# 527 2020-03-15         Norte    AM    1.0       0     8
# 542 2020-03-16  Centro-Oeste    MS    2.0       0     9
# 573 2020-03-17      Nordeste    CE    5.0       0    10
# 629 2020-03-19      Nordeste    PB    1.0       0    11
# 634 2020-03-19         Norte    AC    3.0       0    11
# 637 2020-03-19         Norte    PA    1.0       0    11
# 640 2020-03-19         Norte    TO    1.0       0    11
# 651 2020-03-20  Centro-Oeste    MT    1.0       0    12
# 658 2020-03-20      Nordeste    PI    3.0       0    12
# 663 2020-03-20         Norte    AP    1.0       0    12
# 665 2020-03-20         Norte    RO    1.0       0    12
# 682 2020-03-21      Nordeste    MA    1.0       0    13
# 720 2020-03-22         Norte    RR    2.0       0    14

# %% [markdown]
# Rank por 10 casos

# %%
#Rank com desempate --> deu mesma correlacao
# df_more_10 = df_alpha_no_sp[df_alpha_no_sp["cases"]>=10]
# df_more_10 = df_more_10[~df_more_10.duplicated(subset=["state"])]
# df_more_10['rank_date']=df_more_10["date"].rank(method='dense',ascending=False).astype(int)
# df_more_10["rank"] = df_more_10[["rank_date","cases"]].apply(tuple,axis=1)\
#              .rank(method='dense',ascending=False).astype(int)

# %%
#Rank sem desempate na data
df_more_10 = df_alpha_no_sp[df_alpha_no_sp["cases"]>=10]
df_more_10 = df_more_10[~df_more_10.duplicated(subset=["state"])]
df_more_10["rank"] = df_more_10["date"].rank(method='dense').astype(int)
df_more_10
# Out:
#            date        region state  cases  deaths  rank
# 427  2020-03-11       Sudeste    RJ   13.0       0     1
# 540  2020-03-16  Centro-Oeste    DF   13.0       0     2
# 576  2020-03-17      Nordeste    PE   16.0       0     3
# 592  2020-03-17           Sul    RS   10.0       0     3
# 615  2020-03-18       Sudeste    MG   15.0       0     4
# 618  2020-03-18           Sul    PR   13.0       0     4
# 620  2020-03-18           Sul    SC   10.0       0     4
# 622  2020-03-19  Centro-Oeste    GO   12.0       0     5
# 626  2020-03-19      Nordeste    BA   30.0       0     5
# 627  2020-03-19      Nordeste    CE   20.0       0     5
# 641  2020-03-19       Sudeste    ES   11.0       0     5
# 677  2020-03-21  Centro-Oeste    MS   16.0       0     6
# 687  2020-03-21      Nordeste    SE   10.0       0     6
# 689  2020-03-21         Norte    AM   11.0       0     6
# 715  2020-03-22         Norte    AC   11.0       0     7
# 740  2020-03-23      Nordeste    RN   13.0       0     8
# 787  2020-03-25      Nordeste    AL   11.0       0     9
# 813  2020-03-26  Centro-Oeste    MT   11.0       0    10
# 817  2020-03-26      Nordeste    MA   10.0       0    10
# 826  2020-03-26         Norte    PA   13.0       0    10
# 855  2020-03-27         Norte    RR   10.0       0    11
# 872  2020-03-28      Nordeste    PB   14.0       0    12
# 874  2020-03-28      Nordeste    PI   11.0       1    12
# 937  2020-03-30         Norte    TO   10.0       0    13
# 960  2020-03-31         Norte    AP   10.0       0    14
# 1016 2020-04-02         Norte    RO   10.0       1    15

# %% [markdown]
# Calculo de viagem de probabilidade por estado a partir do estado de SP

# %%
#Calculando probabilidade de viajar de SP para outros estados
df_prob_sp = df_prob[df_prob["uf_origem"]=="SP"] 
total_pass_sp = df_prob_sp["passageiros_total"].sum()
df_prob_sp_uf = pd.DataFrame(df_prob_sp.groupby(["uf_destino"])["passageiros_total"].sum())
df_prob_sp_uf["prob_viagem_sp"] = df_prob_sp_uf["passageiros_total"]/total_pass_sp
df_prob_sp_uf
# Out:
#             passageiros_total  prob_viagem_sp
# uf_destino
# AC                      178.0        0.000007
# AL                    37529.0        0.001400
# AM                    84663.0        0.003159
# AP                     1052.0        0.000039
# BA                  1337603.0        0.049916
# CE                   218485.0        0.008153
# DF                  1524573.0        0.056894
# ES                   508938.0        0.018992
# GO                   807744.0        0.030143
# MA                    13519.0        0.000504
# MG                  2071848.0        0.077317
# MS                   618395.0        0.023077
# MT                    80150.0        0.002991
# PA                    59467.0        0.002219
# PB                    24523.0        0.000915
# PE                   647366.0        0.024158
# PI                    74973.0        0.002798
# PR                  1662952.0        0.062058
# RJ                  4018677.0        0.149968
# RN                    11399.0        0.000425
# RO                    16941.0        0.000632
# RR                    17589.0        0.000656
# RS                  1508926.0        0.056310
# SC                  1265519.0        0.047226
# SE                   104545.0        0.003901
# SP                 10051731.0        0.375107
# TO                    27661.0        0.001032

# %% [markdown]
# Calcular correlacao com os casos de COVID da alpha

# %%
#Realizando merge de df
df_alpha_uf_1 = df_more_1.merge(df_prob_sp_uf, left_on="state", right_on = "uf_destino")
df_alpha_uf_10 = df_more_10.merge(df_prob_sp_uf, left_on="state", right_on = "uf_destino")

# %%
df_alpha_uf_1
# Out:
#          date        region state  cases  deaths  rank  passageiros_total  \
# 0  2020-03-05       Sudeste    RJ    1.0       0     1          4018677.0
# 1  2020-03-06      Nordeste    BA    1.0       0     2          1337603.0
# 2  2020-03-06       Sudeste    ES    1.0       0     2           508938.0
# 3  2020-03-07  Centro-Oeste    DF    1.0       0     3          1524573.0
# 4  2020-03-08      Nordeste    AL    1.0       0     4            37529.0
# 5  2020-03-08       Sudeste    MG    1.0       0     4          2071848.0
# 6  2020-03-10           Sul    RS    1.0       0     5          1508926.0
# 7  2020-03-12      Nordeste    PE    2.0       0     6           647366.0
# 8  2020-03-12           Sul    PR    6.0       0     6          1662952.0
# 9  2020-03-13  Centro-Oeste    GO    3.0       0     7           807744.0
# 10 2020-03-13      Nordeste    RN    1.0       0     7            11399.0
# 11 2020-03-13           Sul    SC    2.0       0     7          1265519.0
# 12 2020-03-15      Nordeste    SE    1.0       0     8           104545.0
# 13 2020-03-15         Norte    AM    1.0       0     8            84663.0
# 14 2020-03-16  Centro-Oeste    MS    2.0       0     9           618395.0
# 15 2020-03-17      Nordeste    CE    5.0       0    10           218485.0
# 16 2020-03-19      Nordeste    PB    1.0       0    11            24523.0
# 17 2020-03-19         Norte    AC    3.0       0    11              178.0
# 18 2020-03-19         Norte    PA    1.0       0    11            59467.0
# 19 2020-03-19         Norte    TO    1.0       0    11            27661.0
# 20 2020-03-20  Centro-Oeste    MT    1.0       0    12            80150.0
# 21 2020-03-20      Nordeste    PI    3.0       0    12            74973.0
# 22 2020-03-20         Norte    AP    1.0       0    12             1052.0
# 23 2020-03-20         Norte    RO    1.0       0    12            16941.0
# 24 2020-03-21      Nordeste    MA    1.0       0    13            13519.0
# 25 2020-03-22         Norte    RR    2.0       0    14            17589.0
#
#     prob_viagem_sp
# 0         0.149968
# 1         0.049916
# 2         0.018992
# 3         0.056894
# 4         0.001400
# 5         0.077317
# 6         0.056310
# 7         0.024158
# 8         0.062058
# 9         0.030143
# 10        0.000425
# 11        0.047226
# 12        0.003901
# 13        0.003159
# 14        0.023077
# 15        0.008153
# 16        0.000915
# 17        0.000007
# 18        0.002219
# 19        0.001032
# 20        0.002991
# 21        0.002798
# 22        0.000039
# 23        0.000632
# 24        0.000504
# 25        0.000656

# %% [markdown]
# Avaliando correlacao com rank a partir de 1 caso

# %%
avaliar_corr(df_alpha_uf_1[["rank","prob_viagem_sp"]], "rank")
# Out:
#                      r              p
# rank            1.0000  2.315232e-189
# prob_viagem_sp -0.7534   8.904206e-06

# %%
df_alpha_uf_10
# Out:
#          date        region state  cases  deaths  rank  passageiros_total  \
# 0  2020-03-11       Sudeste    RJ   13.0       0     1          4018677.0
# 1  2020-03-16  Centro-Oeste    DF   13.0       0     2          1524573.0
# 2  2020-03-17      Nordeste    PE   16.0       0     3           647366.0
# 3  2020-03-17           Sul    RS   10.0       0     3          1508926.0
# 4  2020-03-18       Sudeste    MG   15.0       0     4          2071848.0
# 5  2020-03-18           Sul    PR   13.0       0     4          1662952.0
# 6  2020-03-18           Sul    SC   10.0       0     4          1265519.0
# 7  2020-03-19  Centro-Oeste    GO   12.0       0     5           807744.0
# 8  2020-03-19      Nordeste    BA   30.0       0     5          1337603.0
# 9  2020-03-19      Nordeste    CE   20.0       0     5           218485.0
# 10 2020-03-19       Sudeste    ES   11.0       0     5           508938.0
# 11 2020-03-21  Centro-Oeste    MS   16.0       0     6           618395.0
# 12 2020-03-21      Nordeste    SE   10.0       0     6           104545.0
# 13 2020-03-21         Norte    AM   11.0       0     6            84663.0
# 14 2020-03-22         Norte    AC   11.0       0     7              178.0
# 15 2020-03-23      Nordeste    RN   13.0       0     8            11399.0
# 16 2020-03-25      Nordeste    AL   11.0       0     9            37529.0
# 17 2020-03-26  Centro-Oeste    MT   11.0       0    10            80150.0
# 18 2020-03-26      Nordeste    MA   10.0       0    10            13519.0
# 19 2020-03-26         Norte    PA   13.0       0    10            59467.0
# 20 2020-03-27         Norte    RR   10.0       0    11            17589.0
# 21 2020-03-28      Nordeste    PB   14.0       0    12            24523.0
# 22 2020-03-28      Nordeste    PI   11.0       1    12            74973.0
# 23 2020-03-30         Norte    TO   10.0       0    13            27661.0
# 24 2020-03-31         Norte    AP   10.0       0    14             1052.0
# 25 2020-04-02         Norte    RO   10.0       1    15            16941.0
#
#     prob_viagem_sp
# 0         0.149968
# 1         0.056894
# 2         0.024158
# 3         0.056310
# 4         0.077317
# 5         0.062058
# 6         0.047226
# 7         0.030143
# 8         0.049916
# 9         0.008153
# 10        0.018992
# 11        0.023077
# 12        0.003901
# 13        0.003159
# 14        0.000007
# 15        0.000425
# 16        0.001400
# 17        0.002991
# 18        0.000504
# 19        0.002219
# 20        0.000656
# 21        0.000915
# 22        0.002798
# 23        0.001032
# 24        0.000039
# 25        0.000632

# %% [markdown]
# Avaliando correlacao com rank a partir de 10 casos

# %%
avaliar_corr(df_alpha_uf_10[["rank","prob_viagem_sp"]], "rank")
# Out:
#                      r              p
# rank            1.0000  2.315232e-189
# prob_viagem_sp -0.8603   1.756760e-08

# %% [markdown]
# ### Variante Gamma

# %% [markdown]
# Por cidade

# %% [markdown]
# Por estado

# %%
#Removendo o estado de AM da análise
df_gamma_no_am = df_gamma[df_gamma["uf"]!="AM"]

# %%
#Rank sem desempate na data
df_more_10 = df_gamma_no_am[df_gamma_no_am["cases"]>=10]
df_more_10 = df_more_10[~df_more_10.duplicated(subset=["state"])]
df_more_10["rank"] = df_more_10["Collection date"].rank(method='dense').astype(int)
df_more_10
# Out:
#            Accession ID Collection date Submission date  \
# 49299  EPI_ISL_11496650      2021-01-01      2022-03-28
# 32613   EPI_ISL_1086048      2021-01-14      2021-02-26
# 50373   EPI_ISL_2245177      2021-01-18      2021-05-24
# 40501   EPI_ISL_2661915      2021-01-21      2021-06-24
# 5391    EPI_ISL_1067735      2021-01-23      2021-02-24
# 12040   EPI_ISL_1213192      2021-01-26      2021-03-11
# 48062   EPI_ISL_1533992      2021-01-27      2021-04-10
# 48886   EPI_ISL_2645659      2021-01-27      2021-06-22
# 53274   EPI_ISL_2245111      2021-01-28      2021-05-24
# 45711   EPI_ISL_2245062      2021-01-30      2021-05-24
# 2465    EPI_ISL_4880353      2021-01-31      2021-10-05
# 46573   EPI_ISL_3048764      2021-01-31      2021-07-23
# 52277  EPI_ISL_11396740      2021-01-31      2022-03-25
# 53029   EPI_ISL_1465216      2021-02-01      2021-04-02
# 8890    EPI_ISL_2614197      2021-02-03      2021-06-18
# 12656   EPI_ISL_2660490      2021-02-03      2021-06-24
# 41937   EPI_ISL_2488789      2021-02-11      2021-06-11
# 52619   EPI_ISL_2536305      2021-02-16      2021-06-15
# 3905    EPI_ISL_2645623      2021-02-17      2021-06-22
# 53553   EPI_ISL_2196212      2021-02-19      2021-05-21
# 47625   EPI_ISL_2756440      2021-02-20      2021-06-30
# 11376   EPI_ISL_3553618      2021-02-22      2021-08-22
# 47137  EPI_ISL_13350828      2021-02-22      2022-06-17
# 3564    EPI_ISL_3553594      2021-02-23      2021-08-22
# 128     EPI_ISL_4600557      2021-02-24      2021-09-29
# 39910   EPI_ISL_1520108      2021-03-02      2021-04-09
#
#                                                 Location      continent  \
# 49299          South America / Brazil / Para / Primavera  South America
# 32613           South America / Brazil / Sao Paulo / Jau  South America
# 50373  South America / Brazil / Goias / Aparecida de ...  South America
# 40501         South America / Brazil / Ceara / Fortaleza  South America
# 5391                      South America / Brazil / Bahia  South America
# 12040  South America / Brazil / Rio Grande do Norte /...  South America
# 48062  South America / Brazil / Santa Catarina / Flor...  South America
# 48886          South America / Brazil / Alagoas / MACEIO  South America
# 53274       South America / Brazil / Roraima / Boa Vista  South America
# 45711    South America / Brazil / Acre / Rodrigues Alves  South America
# 2465   South America / Brazil / Parana / Almirante Ta...  South America
# 46573  South America / Brazil / Rio Grande do Sul / P...  South America
# 52277            South America / Brazil / Amapa / Macapa  South America
# 53029       South America / Brazil / Maranhao / Sao Luis  South America
# 8890   South America / Brazil / Rio de Janeiro / RIO ...  South America
# 12656  South America / Brazil / Minas Gerais / PATROC...  South America
# 41937                South America / Brazil / Pernambuco  South America
# 52619     South America / Brazil / Paraiba / Joao Pessoa  South America
# 3905     South America / Brazil / Espirito Santo / SERRA  South America
# 53553         South America / Brazil / Sergipe / Aracaju  South America
# 47625        South America / Brazil / Tocantins / Palmas  South America
# 11376      South America / Brazil / Mato Grosso / Cuiaba  South America
# 47137          South America / Brazil / Federal District  South America
# 3564   South America / Brazil / Mato Grosso do Sul / ...  South America
# 128            South America / Brazil / Piaui / Teresina  South America
# 39910    South America / Brazil / Rondonia / Porto Velho  South America
#
#       country                state          municipality  uf  case  cases  \
# 49299  Brazil                 PARA             Primavera  PA     1     10
# 32613  Brazil            SAO PAULO                   Jau  SP     1     10
# 50373  Brazil                GOIAS  Aparecida de Goiania  GO     1     10
# 40501  Brazil                CEARA             Fortaleza  CE     1     10
# 5391   Brazil                BAHIA                  None  BA     1     10
# 12040  Brazil  RIO GRANDE DO NORTE                 Natal  RN     1     10
# 48062  Brazil       SANTA CATARINA         Florianopolis  SC     1     10
# 48886  Brazil              ALAGOAS                MACEIO  AL     1     10
# 53274  Brazil              RORAIMA             Boa Vista  RR     1     10
# 45711  Brazil                 ACRE       Rodrigues Alves  AC     1     10
# 2465   Brazil               PARANA   Almirante Tamandare  PR     1     10
# 46573  Brazil    RIO GRANDE DO SUL          Porto Alegre  RS     1     10
# 52277  Brazil                AMAPA                Macapa  AP     1     10
# 53029  Brazil             MARANHAO              Sao Luis  MA     1     10
# 8890   Brazil       RIO DE JANEIRO        RIO DE JANEIRO  RJ     1     10
# 12656  Brazil         MINAS GERAIS            PATROCINIO  MG     1     10
# 41937  Brazil           PERNAMBUCO                  None  PE     1     10
# 52619  Brazil              PARAIBA           Joao Pessoa  PB     1     10
# 3905   Brazil       ESPIRITO SANTO                 SERRA  ES     1     10
# 53553  Brazil              SERGIPE               Aracaju  SE     1     10
# 47625  Brazil            TOCANTINS                Palmas  TO     1     10
# 11376  Brazil          MATO GROSSO                Cuiaba  MT     1     10
# 47137  Brazil     DISTRITO FEDERAL                  None  DF     1     10
# 3564   Brazil   MATO GROSSO DO SUL          Campo Grande  MS     1     10
# 128    Brazil                PIAUI              Teresina  PI     1     10
# 39910  Brazil             RONDONIA           Porto Velho  RO     1     10
#
#        rank
# 49299     1
# 32613     2
# 50373     3
# 40501     4
# 5391      5
# 12040     6
# 48062     7
# 48886     7
# 53274     8
# 45711     9
# 2465     10
# 46573    10
# 52277    10
# 53029    11
# 8890     12
# 12656    12
# 41937    13
# 52619    14
# 3905     15
# 53553    16
# 47625    17
# 11376    18
# 47137    18
# 3564     19
# 128      20
# 39910    21

# %% [markdown]
# Calculo de viagem de probabilidade por estado a partir do estado de AM

# %%
#Calculando probabilidade de viajar de AM para outros estados
df_prob_am = df_prob[df_prob["uf_origem"]=="AM"] 
total_pass_am = df_prob_am["passageiros_total"].sum()
df_prob_am_uf = pd.DataFrame(df_prob_am.groupby(["uf_destino"])["passageiros_total"].sum())
df_prob_am_uf["prob_viagem_am"] = df_prob_am_uf["passageiros_total"]/total_pass_am
df_prob_am_uf
# Out:
#             passageiros_total  prob_viagem_am
# uf_destino
# AC                    23992.0        0.018305
# AL                        5.0        0.000004
# AM                   255089.0        0.194625
# AP                      133.0        0.000101
# BA                      352.0        0.000269
# CE                   111381.0        0.084980
# DF                   282918.0        0.215857
# MG                     2716.0        0.002072
# MS                       41.0        0.000031
# MT                       50.0        0.000038
# PA                   192514.0        0.146882
# PE                    54305.0        0.041433
# PR                       33.0        0.000025
# RJ                    94260.0        0.071917
# RO                   100367.0        0.076577
# RR                    87002.0        0.066380
# RS                    17289.0        0.013191
# SC                      943.0        0.000719
# SP                    87117.0        0.066467
# TO                      164.0        0.000125

# %%
df_prob_am_uf.shape
#Isso significa que a 7 estados estão fora da contagem pois não há fluxo direto de manaus para esses estados, ao menos nos nossos dados
# Out:
# (20, 2)

# %% [markdown]
# Calcular correlacao com os casos de COVID da gamma

# %%
df_gamma_uf_10 = df_more_10.merge(df_prob_am_uf, left_on="uf", right_on = "uf_destino")

# %%
df_gamma_uf_10
# Out:
#         Accession ID Collection date Submission date  \
# 0   EPI_ISL_11496650      2021-01-01      2022-03-28
# 1    EPI_ISL_1086048      2021-01-14      2021-02-26
# 2    EPI_ISL_2661915      2021-01-21      2021-06-24
# 3    EPI_ISL_1067735      2021-01-23      2021-02-24
# 4    EPI_ISL_1533992      2021-01-27      2021-04-10
# 5    EPI_ISL_2645659      2021-01-27      2021-06-22
# 6    EPI_ISL_2245111      2021-01-28      2021-05-24
# 7    EPI_ISL_2245062      2021-01-30      2021-05-24
# 8    EPI_ISL_4880353      2021-01-31      2021-10-05
# 9    EPI_ISL_3048764      2021-01-31      2021-07-23
# 10  EPI_ISL_11396740      2021-01-31      2022-03-25
# 11   EPI_ISL_2614197      2021-02-03      2021-06-18
# 12   EPI_ISL_2660490      2021-02-03      2021-06-24
# 13   EPI_ISL_2488789      2021-02-11      2021-06-11
# 14   EPI_ISL_2756440      2021-02-20      2021-06-30
# 15   EPI_ISL_3553618      2021-02-22      2021-08-22
# 16  EPI_ISL_13350828      2021-02-22      2022-06-17
# 17   EPI_ISL_3553594      2021-02-23      2021-08-22
# 18   EPI_ISL_1520108      2021-03-02      2021-04-09
#
#                                              Location      continent country  \
# 0           South America / Brazil / Para / Primavera  South America  Brazil
# 1            South America / Brazil / Sao Paulo / Jau  South America  Brazil
# 2          South America / Brazil / Ceara / Fortaleza  South America  Brazil
# 3                      South America / Brazil / Bahia  South America  Brazil
# 4   South America / Brazil / Santa Catarina / Flor...  South America  Brazil
# 5           South America / Brazil / Alagoas / MACEIO  South America  Brazil
# 6        South America / Brazil / Roraima / Boa Vista  South America  Brazil
# 7     South America / Brazil / Acre / Rodrigues Alves  South America  Brazil
# 8   South America / Brazil / Parana / Almirante Ta...  South America  Brazil
# 9   South America / Brazil / Rio Grande do Sul / P...  South America  Brazil
# 10            South America / Brazil / Amapa / Macapa  South America  Brazil
# 11  South America / Brazil / Rio de Janeiro / RIO ...  South America  Brazil
# 12  South America / Brazil / Minas Gerais / PATROC...  South America  Brazil
# 13                South America / Brazil / Pernambuco  South America  Brazil
# 14        South America / Brazil / Tocantins / Palmas  South America  Brazil
# 15      South America / Brazil / Mato Grosso / Cuiaba  South America  Brazil
# 16          South America / Brazil / Federal District  South America  Brazil
# 17  South America / Brazil / Mato Grosso do Sul / ...  South America  Brazil
# 18    South America / Brazil / Rondonia / Porto Velho  South America  Brazil
#
#                  state         municipality  uf  case  cases  rank  \
# 0                 PARA            Primavera  PA     1     10     1
# 1            SAO PAULO                  Jau  SP     1     10     2
# 2                CEARA            Fortaleza  CE     1     10     4
# 3                BAHIA                 None  BA     1     10     5
# 4       SANTA CATARINA        Florianopolis  SC     1     10     7
# 5              ALAGOAS               MACEIO  AL     1     10     7
# 6              RORAIMA            Boa Vista  RR     1     10     8
# 7                 ACRE      Rodrigues Alves  AC     1     10     9
# 8               PARANA  Almirante Tamandare  PR     1     10    10
# 9    RIO GRANDE DO SUL         Porto Alegre  RS     1     10    10
# 10               AMAPA               Macapa  AP     1     10    10
# 11      RIO DE JANEIRO       RIO DE JANEIRO  RJ     1     10    12
# 12        MINAS GERAIS           PATROCINIO  MG     1     10    12
# 13          PERNAMBUCO                 None  PE     1     10    13
# 14           TOCANTINS               Palmas  TO     1     10    17
# 15         MATO GROSSO               Cuiaba  MT     1     10    18
# 16    DISTRITO FEDERAL                 None  DF     1     10    18
# 17  MATO GROSSO DO SUL         Campo Grande  MS     1     10    19
# 18            RONDONIA          Porto Velho  RO     1     10    21
#
#     passageiros_total  prob_viagem_am
# 0            192514.0        0.146882
# 1             87117.0        0.066467
# 2            111381.0        0.084980
# 3               352.0        0.000269
# 4               943.0        0.000719
# 5                 5.0        0.000004
# 6             87002.0        0.066380
# 7             23992.0        0.018305
# 8                33.0        0.000025
# 9             17289.0        0.013191
# 10              133.0        0.000101
# 11            94260.0        0.071917
# 12             2716.0        0.002072
# 13            54305.0        0.041433
# 14              164.0        0.000125
# 15               50.0        0.000038
# 16           282918.0        0.215857
# 17               41.0        0.000031
# 18           100367.0        0.076577

# %% [markdown]
# Avaliando correlacao com rank a partir de 10 casos

# %%
avaliar_corr(df_gamma_uf_10[["rank","prob_viagem_am"]], "rank")
# Out:
#                      r              p
# rank            1.0000  1.679092e-134
# prob_viagem_am -0.1425   5.604743e-01

# %% [markdown]
# ## Rotas Mais prováveis
